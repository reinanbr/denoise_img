# %%
import PIL as pl
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = pl.Image.open('test.png')

r,g,b = img.split()

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x423>

# %%
r.histogram()
# Out:
# [2745,
#  953,
#  931,
#  1293,
#  1424,
#  1663,
#  2059,
#  2379,
#  2964,
#  3290,
#  3826,
#  4279,
#  4749,
#  5290,
#  5820,
#  6120,
#  6395,
#  6553,
#  6655,
#  6436,
#  6191,
#  5913,
#  5799,
#  5444,
#  5197,
#  4801,
#  4508,
#  4379,
#  4021,
#  3878,
#  3559,
#  3344,
#  3211,
#  3054,
#  2932,
#  2779,
#  2715,
#  2565,
#  2539,
#  2331,
#  2198,
#  2220,
#  2055,
#  2088,
#  1880,
#  1916,
#  1829,
#  1822,
#  1825,
#  1771,
#  1872,
#  1686,
#  1758,
#  1668,
#  1683,
#  1642,
#  1605,
#  1514,
#  1523,
#  1516,
#  1396,
#  1386,
#  1240,
#  1238,
#  1157,
#  1088,
#  1082,
#  1011,
#  992,
#  1000,
#  920,
#  932,
#  849,
#  812,
#  812,
#  819,
#  755,
#  708,
#  720,
#  731,
#  672,
#  640,
#  666,
#  631,
#  644,
#  626,
#  568,
#  576,
#  561,
#  523,
#  582,
#  524,
#  570,
#  510,
#  494,
#  519,
#  519,
#  511,
#  490,
#  507,
#  450,
#  453,
#  466,
#  473,
#  446,
#  430,
#  444,
#  455,
#  435,
#  414,
#  442,
#  438,
#  462,
#  397,
#  425,
#  408,
# ...

# %%
g.histogram()
# Out:
# [2688,
#  897,
#  923,
#  1074,
#  1320,
#  1553,
#  1861,
#  2256,
#  2668,
#  3142,
#  3652,
#  4114,
#  4618,
#  5260,
#  5734,
#  6228,
#  6476,
#  6792,
#  6802,
#  6820,
#  6531,
#  6281,
#  6113,
#  5720,
#  5401,
#  5059,
#  4767,
#  4583,
#  4186,
#  3988,
#  3668,
#  3456,
#  3228,
#  3091,
#  2995,
#  2775,
#  2760,
#  2550,
#  2427,
#  2361,
#  2205,
#  2212,
#  2096,
#  2003,
#  1834,
#  1827,
#  1754,
#  1731,
#  1718,
#  1687,
#  1723,
#  1649,
#  1601,
#  1615,
#  1578,
#  1585,
#  1486,
#  1444,
#  1545,
#  1386,
#  1345,
#  1369,
#  1327,
#  1223,
#  1260,
#  1259,
#  1116,
#  1173,
#  1121,
#  1095,
#  1059,
#  1114,
#  1036,
#  1021,
#  1006,
#  919,
#  901,
#  896,
#  912,
#  894,
#  867,
#  787,
#  796,
#  829,
#  839,
#  722,
#  740,
#  714,
#  695,
#  697,
#  698,
#  692,
#  650,
#  600,
#  590,
#  619,
#  575,
#  612,
#  583,
#  561,
#  580,
#  576,
#  628,
#  638,
#  632,
#  596,
#  627,
#  644,
#  712,
#  720,
#  640,
#  692,
#  665,
#  677,
#  662,
# ...

# %%
b.histogram()
# Out:
# [747,
#  160,
#  1712,
#  641,
#  894,
#  1420,
#  1329,
#  1596,
#  1899,
#  2268,
#  2710,
#  3094,
#  3492,
#  4189,
#  4816,
#  5290,
#  5787,
#  6062,
#  6437,
#  6763,
#  6668,
#  6400,
#  6515,
#  6297,
#  6094,
#  5565,
#  5469,
#  5054,
#  4770,
#  4467,
#  4078,
#  3929,
#  3677,
#  3370,
#  3236,
#  3018,
#  2920,
#  2679,
#  2628,
#  2434,
#  2311,
#  2141,
#  2015,
#  2069,
#  1866,
#  1799,
#  1730,
#  1651,
#  1556,
#  1540,
#  1419,
#  1450,
#  1396,
#  1377,
#  1322,
#  1288,
#  1277,
#  1223,
#  1205,
#  1178,
#  1159,
#  1057,
#  1116,
#  1106,
#  1125,
#  1059,
#  1019,
#  1011,
#  954,
#  919,
#  989,
#  885,
#  965,
#  934,
#  824,
#  790,
#  807,
#  835,
#  856,
#  828,
#  851,
#  824,
#  838,
#  835,
#  804,
#  767,
#  789,
#  802,
#  772,
#  714,
#  750,
#  716,
#  753,
#  706,
#  684,
#  683,
#  712,
#  664,
#  654,
#  615,
#  612,
#  619,
#  591,
#  594,
#  553,
#  610,
#  557,
#  513,
#  503,
#  519,
#  510,
#  447,
#  510,
#  505,
#  499,
#  476,
#  445,
# ...

# %%
plt.plot(r.histogram())
plt.plot(g.histogram())
plt.plot(b.histogram())

# %%
img_cv = cv2.imread('test.png')
plt.imshow(img_cv)

# %%
plt.imshow(img_cv*.003)
